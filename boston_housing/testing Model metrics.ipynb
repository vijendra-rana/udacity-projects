# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.learning_curve import learning_curve
from sklearn.cross_validation import KFold
from sklearn.metrics import explained_variance_score, make_scorer
import numpy as np

# %%
# Set the learning curve parameters; you'll need this for learning_curves
size = 1000
cv = KFold(size,shuffle=True)
score = make_scorer(explained_variance_score)

# %%
cv
# Out:
# sklearn.cross_validation.KFold(n=1000, n_folds=3, shuffle=True, random_state=None)

# %%
score
# Out:
# make_scorer(explained_variance_score)

# %%
X = np.round(np.reshape(np.random.normal(scale=5,size=2*size),(-1,2)),2)
y = np.array([[np.sin(x[0]+np.sin(x[1]))] for x in X])

# %%
X.shape
# Out:
# (1000L, 2L)

# %%
y.shape
# Out:
# (1000L, 1L)

# %%
reg = DecisionTreeRegressor()
reg.fit(X,y)
print "Regressor score: {:.4f}".format(reg.score(X,y))
# Out:
# Regressor score: 1.0000

# %%
# TODO: Use learning_curve imported above to create learning curves for both the
# training data and testing data. You'll need 'size', 'cv' and 'score' from above.
    
training_sizes, training_scores, testing_scores = learning_curve(reg,X,y,cv = cv,scoring = score)

# %%
# Plot aesthetics
plt.plot(training_scores,label ='training')
plt.plot(testing_scores,label ='testing')
plt.ylim(-0.1, 1.1)
plt.ylabel("Curve Score")
plt.xlabel("Training Points")
plt.legend(bbox_to_anchor=(1.1, 1.1))
plt.show()

# %%
testing_scores
# Out:
# array([[-0.0452514 , -0.02648325, -0.26219113],
#        [ 0.38666331,  0.23663357,  0.24495947],
#        [ 0.4310808 ,  0.49151804,  0.29400095],
#        [ 0.49091086,  0.4546274 ,  0.54357625],
#        [ 0.50671309,  0.54814473,  0.54791867]])

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
a.mean()
# Out:
# 3.5

# %%
a.mean(axis =1)
# Out:
# array([ 2.,  5.])

# %%
testing_scores.mean(axis = 1)
# Out:
# array([-0.11130859,  0.28941878,  0.40553326,  0.4963715 ,  0.53425883])
